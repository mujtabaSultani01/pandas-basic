# %% [markdown]
# ## Pandas-basic
# Pandas is one of the most popular Python libraries for Data Science and Analytics. I like to say it’s the “SQL of Python.” Why? Because pandas helps you to manage two-dimensional data tables in Python. Of course, it has many more features. (E.g. lot of the popular machine learning libraries in Python are built on the top of pandas.)
#
#  => Tomi Mester
#
# **Note:** *This is a hands-on tutorial, so I recommend doing the coding part with me!*

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/dcqPhpY7tWk" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/dcqPhpY7tWk" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# ### Pandas installation
# **Pandas** comes with **Anaconda distribution**, os once you installed Anaconda, you will get Pandas for free. the 2nd way of installing Pandas is **'pip'**=> "*pip install pandas*" command will install pandas for you and you'll get pandas module.

# %%
# To check whether Pandas is successfully installed or not(if it doesn't give the error, it means it's installed...):
import pandas as pd

# %% [markdown]
# #### Data Frame (df) basics in pandas:
# Data frame is a main object in pandas. it is used to represent data with rows and columns (Tabular or excell spread sheet like data). Tabular is a collection of rows and columns & we use it in pandas to represent data in tabular form.

# %%
# read_csv() function read the csv files.
df = pd.read_csv('CSV Files/nyc_weather.csv')
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
# head() function display the top n rows.
df.head(4)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345

# %%
# tail() function display the bottom n rows.
df.tail(4)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 27             234
# 28             298
# 29             257
# 30             241

# %%
# We can create structured data using python dictionary:
all_electronic = {
    'name': ['Mobile', 'Laptop', 'Camera'],
    'price': ['140$', '580$', '180$'],
    'made in': ['US', 'UK', 'Chaina']
}
df1 = pd.DataFrame(all_electronic)
df1
# Out:
#      name price made in
# 0  Mobile  140$      US
# 1  Laptop  580$      UK
# 2  Camera  180$  Chaina

# %%
# To check the shape of dataframe, we use shape() function. It shows us the number of rows and columns.
df.shape
# Out:
# (31, 11)

# %%
df1.shape
# Out:
# (3, 3)

# %%
# We can assigns the rows and columns number to variables.
rows, columns = df.shape

# %%
# rows stored the number of row.
rows
# Out:
# 31

# %%
# columns stored the number of columns.
columns
# Out:
# 11

# %%
# To know which columns we have in our DataFrame:
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
# We can display a specific rows from DataFrame.
df[3:10]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 3   1/4/2016           25         9        44                 30.05
# 4   1/5/2016           20        -3        41                 30.57
# 5   1/6/2016           33         4        35                 30.50
# 6   1/7/2016           39        11        33                 30.28
# 7   1/8/2016           39        29        64                 30.20
# 8   1/9/2016           44        38        77                 30.16
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
# 5               10           4.0               0           0    NaN
# 6               10           2.0               0           3    NaN
# 7               10           4.0               0           8    NaN
# ...

# %%
# Didn't show you the first 20 rows.
df[20:]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# ...

# %%
# Show you the first 3 rows:
df[:3]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
# To display a specific columns:
df1[['price']]
# Out:
#   price
# 0  140$
# 1  580$
# 2  180$

# %%
df[['EST', 'Temperature', 'Humidity', 'Events']]
# Out:
#           EST  Temperature  Humidity    Events
# 0    1/1/2016           38        52       NaN
# 1    1/2/2016           36        46       NaN
# 2    1/3/2016           40        47       NaN
# 3    1/4/2016           25        44       NaN
# 4    1/5/2016           20        41       NaN
# 5    1/6/2016           33        35       NaN
# 6    1/7/2016           39        33       NaN
# 7    1/8/2016           39        64       NaN
# 8    1/9/2016           44        77      Rain
# 9   1/10/2016           50        71      Rain
# 10  1/11/2016           33        37       NaN
# 11  1/12/2016           35        53       NaN
# 12  1/13/2016           26        42       NaN
# 13  1/14/2016           30        47       NaN
# 14  1/15/2016           43        62       NaN
# 15  1/16/2016           47        70      Rain
# 16  1/17/2016           36        66  Fog-Snow
# 17  1/18/2016           25        53      Snow
# 18  1/19/2016           22        42       NaN
# ...

# %%
# To display a specific rows and columns:
df_sub = df[['EST', 'Humidity', 'DewPoint', 'Events', 'WindDirDegrees']]
df_sub.head(3)
# Out:
#         EST  Humidity  DewPoint Events  WindDirDegrees
# 0  1/1/2016        52        23    NaN             281
# 1  1/2/2016        46        18    NaN             275
# 2  1/3/2016        47        21    NaN             277

# %%
# To display a column type (Pandas.core.series.Series):
type(df1['name'])
# Out:
# pandas.core.series.Series

# %%
# To find maximum max():
df['Humidity'].max()
# Out:
# 78

# %%
# To find minimum min():
df['Humidity'].min()
# Out:
# 33

# %%
# To find mean():
df['Humidity'].mean()
# Out:
# 51.67741935483871

# %%
# To find sum():
df['Humidity'].sum()
# Out:
# 1602

# %%
# To find Standard deviation std():
df['Humidity'].std()
# Out:
# 11.634394689237006

# %%
# Describe() method will print the statistics on your dataset:
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
# Now! how can we select data from dataset conditionally?
df[df.Temperature >= 35]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 11  1/12/2016           35        15        53                 29.85
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# ...

# %%
# Show us the records which has greater Humidity than 60:
df[df.Humidity >= 60]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 22  1/23/2016           26        21        78                 29.77
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 7                10           4.0               0           8       NaN
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 14                9           5.0               T           2       NaN
# ...

# %%
# To display the only record which has maximum temeperature:
# df[df.Temperature == df.Temperature.max()]
# Or
df[df.Temperature == df['Temperature'].max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
# To display the only day on which the Temperature was minimum:
# df['EST'][df.Temperature == df.Temperature.min()]
# Or
df['EST'][df.Temperature == df['Temperature'].min()]
# Out:
# 4    1/5/2016
# Name: EST, dtype: object

# %%
# To display the only day with minimum Temperature:
df[['EST', 'Temperature']][df.Temperature == df.Temperature.min()]
# Out:
#         EST  Temperature
# 4  1/5/2016           20

# %%
# So, we see the DataFrame (df) has default index which is integer. 
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
# We can change the default index to Date (EST) column: (The benefits of using of changing the default index is that, that we can run loc() function on new index, which give us all the information on that row.)
# inplace=Ture command is necessary,in other case it won't be change.
# We can choose any column as index.
df.set_index('EST', inplace=True)
df
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# ...

# %%
# Now if we run loc() method:
df.loc['1/5/2016']
# Out:
# Temperature                20
# DewPoint                   -3
# Humidity                   41
# Sea Level PressureIn    30.57
# VisibilityMiles            10
# WindSpeedMPH              5.0
# PrecipitationIn             0
# CloudCover                  0
# Events                    NaN
# WindDirDegrees            333
# Name: 1/5/2016, dtype: object

# %%
df.loc['1/10/2016']
# Out:
# Temperature                50
# DewPoint                   46
# Humidity                   71
# Sea Level PressureIn    29.59
# VisibilityMiles             4
# WindSpeedMPH              NaN
# PrecipitationIn           1.8
# CloudCover                  7
# Events                   Rain
# WindDirDegrees            109
# Name: 1/10/2016, dtype: object

# %%
# To reset back to default (integer) index:
df.reset_index(inplace=True)
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %% [markdown]
# Thats Were all for the **first session**.
